# %% [markdown]
# #B1
# Ans - A list is a data structure in Python that is a mutable, or changeable, ordered sequence of elements. Each element or value that is inside of a list is called an item. Just as strings are defined as characters between quotes, lists are defined by having values between square brackets [  ].
# ####Reverse a list -
# By using reverse(), list seqeunce reverse.

# %% [markdown]
# #B2
# Ans - By using pop( ), we can delete last item from a list.

# %% [markdown]
# #B3
# Ans - 25

# %% [markdown]
# #B4
# Ans - Append adds its argument as a single element to the end of a list. The length of the list itself will increase by one.
#
# Extend iterates over its argument adding each element to the list, extending the list. The length of the list will increase by however many elements were in the iterable argument.

# %%
#B5
x = [1,2,2,4,5]
b = max(x)
c = min(x)
d = sum(x)
print('largest number is ' f'{b}')  
print('smallest number is ' f'{c}')  
print('Sum of l is ' f'{d}')
# Out:
# largest number is 5
# smallest number is 1
# Sum of l is 14

# %%
def program(x):
   return b,c,d

# %%
program(x)
# Out:
# (5, 1, 14)

# %% [markdown]
# #B6
# Ans - By using == operator, sum(),len(), we can compare two lists.

# %%
#I1

# %%
#I2
l = [1,1,2,2,3,3]
a = []
for i in l:
    
    if i not in a:

      a.append(i)

# %%
a
# Out:
# [1, 2, 3]

# %%
#I3
l = []
n = int(input('Enter lenth of list  '))

for i in range (0, n):

 y = input('Enter any number  ')
 l.append(y)

a = len(l)

if a == 0:
  print('Empty list')

if  a > 0:
  print('List length is ' f'{a}' )
# Out:
# Enter lenth of list  2
# Enter any number  1
# Enter any number  1
# List length is 2

# %%
#I4
def name(*num):
  a = []

  for i in num:
    
    if i not in a:

      a.append(i)

  return a

# %%
name(5,5,5,4,3,7,5,4,3)
# Out:
# [5, 4, 3, 7]

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
#I5

# %%
#I6
l = [1,1,2,2,3,3]
a = []
for i in l:
    
    if i not in a:

      a.append(i)

# %%
a
# Out:
# [1, 2, 3]

# %%
#I7
l = ['h','e' ,'l','l','o']
''.join(l)
# Out:
# 'hello'

# %%
#A1
import random
random.choice([1,2,3,4,5])

# %%
#A2
l = [8,6,2,3]
l.sort()
a = l[1:2]
print('Second smallest number is  ' f'{a}')
# Out:
# Second smallest number is  [3]

# %%
l
# Out:
# [6, 7, 8, 9]

# %%
#A3
l = ['hello', 'hello',2,2,2,'a','a',9.1,9.1,7,6,6]

l2 = []

for a in l:
   if a not in l2:
      l2.append(a)
      print(l2)
# Out:
# ['hello']
# ['hello', 2]
# ['hello', 2, 'a']
# ['hello', 2, 'a', 9.1]
# ['hello', 2, 'a', 9.1, 7]
# ['hello', 2, 'a', 9.1, 7, 6]

# %%
l2
# Out:
# ['hello', 2, 'a', 9.1, 7, 6]

# %%
#A4
l = [1,2,3,4,5,6]
l2 = [2,3,5]
a = []
d = []

for i in l:
  a.append(i)
  for d in l2:
    
    if a == d:
      print('sublist')
# Out:
#  not sublist

# %%
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
#A5
l = [('Name'),('age'),('city')]

var1 , var2 , var3 = l

print(var1)
print(var2)
print(var3)
# Out:
# Name
# age
# city

# %% [markdown]
# #Tuple

# %% [markdown]
# #B1
# Ans - Tuples are used to store multiple items in a single variable. Tuple is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Set, and Dictionary, all with different qualities and usage. A tuple is a collection which is ordered and unchangeable.
#
# ####Difference
# The key difference between the tuples and lists is that while the tuples are immutable objects the lists are mutable. This means that tuples cannot be changed while the lists can be modified. Tuples are more memory efficient than the lists.

# %%
#B2
t = ('a','b',1,2,2.0,'s')

# %%
type(t)
# Out:
# tuple

# %%
#B3
t = (1,2,3,4)

# %%
t
# Out:
# (1, 2, 3, 4)

# %%
type(t)
# Out:
# tuple

# %%
#B4
t = ('h','e','l','l','o')

''.join(t)
# Out:
# 'hello'

# %%
type(t)
# Out:
# tuple

# %%
t
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
#B5
tuplex =(1,2,3,4)
print( 1 in tuplex)
print( 5 in tuplex)
# Out:
# True
# False

# %%
#B6
t = (1,2,3,4,5)
a = len(t)
print(a)
# Out:
# 5

# %%
#B7
t = (1,2,3,4)
t = list(t)

# %%
type(t)
# Out:
# list

# %%
#I1
t = (1,2,3,4)
t = list(t)

t.reverse()

# %%
t
# Out:
# [4, 3, 2, 1]

# %%
t = tuple(t)

# %%
t
# Out:
# (4, 3, 2, 1)

# %%
#I2
t = (5,6,7)
t = list(t)
t.pop()
# Out:
# 7

# %%
#I3
t = (1,2,3,4,2,2,1,3)
for i in t:
     print(f"{i} comes {t.count(i)} times.")
# Out:
# 1 comes 2 times.
# 2 comes 3 times.
# 3 comes 2 times.
# 4 comes 1 times.
# 2 comes 3 times.
# 2 comes 3 times.
# 1 comes 2 times.
# 3 comes 2 times.

# %%
#A1
t = (1,2,'',3,4,5,'','')
t = list(t)
t1 =[]
for i in t:
  if i != '':
    t1.append(i)

# %%
t1 = tuple(t1)

# %%
t1
# Out:
# (1, 2, 3, 4, 5)

# %%
#A2
t = [('a',1),('b',1),('c',3)]
a = list(zip(*t))
print(a)
# Out:
# [('a', 'b', 'c'), (1, 1, 3)]

# %%
#A3
t = (['a',1],['b',2],['c',3])
d = dict(t)

print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# #Dictionary

# %% [markdown]
# #B1
# Ans -  A dictionary is an unordered and mutable Python container that stores mappings of unique keys to values. Dictionaries are written with curly brackets ({}), including key-value pairs separated by commas (,). A colon (:) separates each key from its value.

# %% [markdown]
# #B2
# Ans - In Python, a Dictionary can be created by placing a sequence of elements within curly {} braces, separated by 'comma'. Dictionary holds pairs of values, one being the Key and the other corresponding pair element being its Key:value
#
# You can get all the keys in the dictionary as a Python List. dict. keys() returns an iterable of type dict_keys().

# %% [markdown]
# #B3
# Ans - Converting a list of tuples into a dictionary is a straightforward thing.
#
# Follow the below steps to complete the code.
#
# Initialize the list with tuples.
# Use the dict to convert given list of tuples into a dictionary.
# Print the resultant dictionary.

# %%
#B4  Incomplete
x = {'b':1,'a':2,'c':3,'d':4}
sorted(x)
# Out:
# ['a', 'b', 'c', 'd']

# %%
#B5
d = {'a':1,'b':2,'c':3}
d1 = {'d':4,'e':5}

d.update(d1)
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
#B6
d = {'a':1,'b':2,'c':3}
a = input('Enter key  ')

if a in d:
    print("key already exists")
else:
   print('key does not exists')
# Out:
# Enter key  b
# key already exists

# %% [markdown]
# #B7
# Ans - The items() method, the keys() method, and the values() method return values you can use to iterate through a dictionary in Python. items() returns both the keys and values in a Python dictionary. keys() returns the keys in a dictionary. values() returns the values in a dictionary. You can also use a for loop to iterate through a Python dictionary.

# %% [markdown]
# #B8
# Ans - The keys() method will return a list of keys available in the dictionary and IF, IN statement will check if the passed key is available in the list.
#
# If the key exists, it returns True else, it returns False .

# %%
#I1

# %%
#I2
d = {'a':1,'b':2,'c':3}
a = input('Enter key  ')
b = input('Enter key  ')
c = input('Enter key  ')

if (a in d or b in d or c in d):
    print("key already exists")
else:
   print('key does not exists')
# Out:
# Enter key  a
# Enter key  b
# Enter key  c
# key already exists

# %%
#I3
d1 = {'a':1,'b':2,'c':3}
d2 = {'d':4,'e':5,'f':6}

d1.update(d2)

# %%
d1
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
#I4
keys = ['name','age','city']
values = ['vasu','25','ahemdabad']

result = dict(zip(keys,values))
print(result)
# Out:
# {'name': 'vasu', 'age': '25', 'city': 'ahemdabad'}

# %%
#I5
d1 = {'a': 100, 'b': 200, 'c':300}

d2 = {'a': 300, 'b': 200, 'd':400}
d = {}
d.update(d1)
d.update(d2)             # d = {'a': 300, 'b': 200, 'c': 300, 'd': 400}

for i, j in d1.items():

    for a, b in d2.items():

        if i == a:
           d[i]=(j+b)
print(d)
# Out:
# {'a': 400, 'b': 400, 'c': 300, 'd': 400}

# %%
#I6 Incomplete
d1 = {'a': 100, 'b': 200, 'c':300,'d':100}
d2 = {}

for i,j in d1.items():
 a == i
 b == j
 if j not in d2:
    d2.update(j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-cd74167d8f75> in <module>()
#       6   d2.update(d1)
#       7   if j not in d2:
# ----> 8     d2.update(j)
#       9
#      10
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# #I7
# Ans - Python zip() method takes iterable or containers and returns a single iterator object, having mapped values from all the containers.
#
# It is used to map the similar index of multiple containers so that they can be used just using a single entity.

# %%
#Example-
keys = ['name','age','city']
values = ['vasu','25','ahemdabad']

result = dict(zip(keys,values))
print(result)
# Out:
# {'name': 'vasu', 'age': '25', 'city': 'ahemdabad'}

# %%
#A1

# %%
#A2

# %%
#A3

# %%
#A4

# %% [markdown]
# #FUNCTIONS

# %%
#B1 Incomplete
def fact(n):


  f = 1

  for i in range(1, n+1):
    f = i*f

# %%
#B2
def num(n):
   for i in range(1,10):
     if n == i:
       print('Number is in given range')

# %%
num(2)
# Out:
# Number is in given range

# %%
#B3 Incomplete
def num(n):
  sum = 0
  for i in range(1 , n):
   if (n % i == 0):
      sum = sum + i

      if sum == n :
        print(f'{n} is perfect number')
      
      else:
          print(f'{n} is not perfect number')

# %%
num(6)
# Out:
# 6 is not perfect number
# 6 is not perfect number
# 6 is perfect number

# %%
#B4

a = input('Enter any word  ')
b = a[::-1]
if a == b:
  print('String is Palindrome')
else:
  print('String is not Palindrome')
# Out:
# Enter any word  radar
# String is Palindrome

# %% [markdown]
# #B5 Incomplete
# Ans - PEP 634 introduced structural pattern matching to Python. Pattern matching involves providing a pattern and an associated action to be taken if the data fits the pattern.

# %%
#B5

# %% [markdown]
# #B6
# Ans - A lambda function is a small anonymous function.
#
# A lambda function can take any number of arguments, but can only have one expression.
# Syntax - lambda arguments: expression
#
# Stub is a simple but incomplete version of a function.Stub files contain type-hinting information of normal Python modules. The full official documentation can be found in the section about stub-files in PEP-484.

# %% [markdown]
# #B7
# Ans - Mainly, there are two types of functions:
#
# User-defined functions – These functions are defined by the user to perform a specific task.
#
#
# Built-in functions – These functions are pre-defined functions in Python.

# %%
#I1
def name():
  def name_fun():            #A function defined inside another function is called a nested function.
                             # Nested functions can access variables of the enclosing scope.
    print('vasudha')
  name_fun()

# %%
name()
# Out:
# vasudha

# %%
#I2
def fun():
    a = 1
    b = 2
    c = 'hello'
print(fun.__code__.co_nlocals)
# Out:
# 3

# %% [markdown]
# #I3
# Ans - Map in Python is a function that works as an iterator to return a result after applying a function to every item of an iterable (tuple, lists, etc.). It is used when you want to apply a single transformation function to all the iterable elements. The iterable and function are passed as arguments to the map in Python.
#
# ###Syntax-
#
# map(function, iterator1,iterator2 ...iteratorN)

# %%
def square(n):
    return n*n
my_list = [2,3,4,5,6,7,8,9]
updated_list = map(square, my_list)
print(updated_list)
print(list(updated_list))
# Out:
# ...
# [4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# #I4
# Ans - The main function in Python acts as the point of execution for any program. Defining the main function in Python programming is a necessity to start the execution of the program as it gets executed only when the program is run directly and not executed when imported as a module.

# %% [markdown]
# #I5
# Ans - *args: Receive multiple arguments as a tuple.
#
#
# **kwargs: Receive multiple keyword arguments as a dictionary.

# %% [markdown]
# #I6
# Ans - __name__ is a built-in variable which evaluates to the name of the current module. Thus it can be used to check whether the current script is being run on its own or being imported somewhere else by combining it with if statement.
#
# ###Purpose of "End"
#
# The “end” parameter of python's print() function is used to format the output printed on the screen. This can be used in loops as well to achieve a pattern in the output.

# %% [markdown]
# #I7
# Ans- len() - The function len() is one of Python's built-in functions. It returns the length of an object. For example, it can return the number of items in a list. You can use the function with many different data types.
#
# ord() - Python ord() function returns the Unicode code from a given character. This function accepts a string of unit length as an argument and returns the Unicode equivalence of the passed argument.

# %% [markdown]
# #A1

# %%
#A2
a = 'hello'
b = a[::-1]
print(b)
# Out:
# olleh

# %% [markdown]
# #Module

# %%
#B1
l = [1,2,3,4,5]
import random
random.choice(l)
# Out:
# 5

# %%
#B2
import random
random.randrange(1,10)
# Out:
# 8

# %%
#B3
import random
random.randint(1,20)
# Out:
# 9

# %%
#B4

# %%
#B5
import random
random.choices([1,2,3,4],k=2)
# Out:
# [1, 2]

# %%
#I1

# %%
#I2                     # math.radians() - convert radians into degree.
import math    
degree = 120                      # math.degrees() - convert degrees into radians.
math.radians(degree)
# Out:
# 2.0943951023931953

# %%
#I3
def Area(b1, b2, h):
    return ((b1 + b2) / 2) * h

# %%
Area(2,2,4)
# Out:
# 8.0

# %%
#I4
def parallelogram(b,h):
  return (b*h)

# %%
parallelogram(2,3)
# Out:
# 6

# %%
#I5 Volume of Cylinder
def vol(r,h):
  import math
  return (math.pi*r*r*h)

# %%
vol(2,3)
# Out:
# 37.69911184307752

# %%
#Surface area of cylinder
def area(r,h):
  import math
  return((2*math.pi*r*h)+(2*math.pi*r*r))

# %%
area(2,3)
# Out:
# 62.83185307179586

# %%
#I6 Incomplete
a = int(input('Enter any number  '))
b = []
for i in range(2,11):
     if (a%i)==0:
      b.append(i)
      c = sum(b)
      print(c)
# Out:
# Enter any number  4
# 2
# 6

# %%
#I7
a = [2.3,7.6,8.9,3.2]
print(max(a))
print(min(a))
# Out:
# 8.9
# 2.3

# %%
#A1
a = [2.45,2.69,2.45,3.45,2.00,0.04,7.25]
c = sum(a)
print('sum is = ' f'{c}')

a.sort()
print(a)
# Out:
# sum is = 20.33
# [0.04, 2.0, 2.45, 2.45, 2.69, 3.45, 7.25]

# %%
#A2
import math
print(math.exp(0))
print(math.sqrt(4))
# Out:
# 1.0
# 2.0

# %%
#A3
